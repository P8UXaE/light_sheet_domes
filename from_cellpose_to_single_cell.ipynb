# %%
import skimage as sk
import matplotlib.pyplot as plt
import numpy as np
import cv2
from copy import copy

# %%
cellpose = sk.io.imread('./../ppujol/zmap/62 t3 hull z map_cp_masks.png')

# %%
for i in range(1, cellpose.max()):
    labels = copy(cellpose)
    labels[labels != i] = 0
    plt.imshow(labels)
    break
