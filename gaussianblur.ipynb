# %%
import skimage as sk
import cv2
import matplotlib.pyplot as plt

# %%
image = sk.io.imread('../ppujol/tempDomes/21-1.tif')
image = cv2.GaussianBlur(image,(11,11),0)
plt.imshow(image)

# %%
import tifffile as tiff

tiff.imsave('../ppujol/tempDomes/21-1-gaussian5x5.tif', image)
# Out:
# /tmp/ipykernel_143629/4057892894.py:3: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave('../ppujol/tempDomes/21-1-gaussian5x5.tif', image)
