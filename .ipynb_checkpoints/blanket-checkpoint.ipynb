# %% [markdown]
# Throw a blanket on the dome. It should cover the figure. Energy minimisation.

# %%
import skimage as sk
from scipy.ndimage import gaussian_filter
from scipy.signal import find_peaks
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from copy import copy
import napari

# %%
image_denoise = sk.io.imread('./domes/domes_n2v/70_denoised.tif')
image = sk.io.imread('./domes/Nice Domes/70.tif')

# %%
viewer = napari.Viewer()
viewer.add_image(image_denoise)
# Out:
# <Image layer 'image_denoise' at 0x27bc249bcd0>

# %%
def clean_image(im):
    non_zero_cols = np.any(im != 0, axis = 0)
    first_non_zero_col = np.argmax(non_zero_cols)
    last_non_zero_col = len(non_zero_cols) - np.argmax(non_zero_cols[::-1]) - 1
    clean_image = im[:, first_non_zero_col:last_non_zero_col + 1]
    return (clean_image, first_non_zero_col, last_non_zero_col)
    
def compute_mean_no_zeros(im):
    '''
    Compute the mean pixel intensity of the image.
    '''
    return np.mean(clean_image(im))

def clean_strip(im, im_d, delta=30):
    c_im, first, last = clean_image(im)
    # print('-'*30)
    # print(c_im.shape, first, last, im_d.shape)
    if (first != 0):
        first_array = np.zeros((im.shape[0], first+delta)) # Create a 2D array full of 0s dimensions of the image and the columns null + 0
        # print(im_d.shape, im_d[:, first+delta:].shape, first_array.shape)
        im_d = np.hstack((first_array, im_d[:, first+delta:]))
    if (first != im.shape[1]):
        last_array = np.zeros((im.shape[0], im.shape[1]-last+delta)) # Create a 2D array full of 0s dimensions of the image and the columns null + 0
        # print(im_d.shape, im_d[:, :last-delta + 1].shape, last_array.shape)
        im_d = np.hstack((im_d[:, :last-delta + 1],last_array))
    # print(im_d.shape)

    return im_d

def clean_strip_stack(im, im_d):
    cleaned = []
    for i, i_d in zip(im, im_d):
        cleaned.append(clean_strip(i, i_d))

    cleaned = np.array(cleaned)        
    return cleaned

# %%
# Select the timeframe to work with and remove the first and last strip by removing this part of the image

im_d = image_denoise[3]
im = image[3]
im_2 = clean_strip(im[470], im_d[470])

im_unstrip = clean_strip_stack(im, im_d)


viewer.add_image(im_unstrip)




# plt.imshow(clean_image(image[3][100]))
# Out:
# <Image layer 'im_unstrip' at 0x27fe0a1a310>

# %%
gaussian = gaussian_filter(im, sigma=2)
viewer.add_image(gaussian)

# %%
gaussian = gaussian_filter(im_unstrip, sigma=2)

plt.figure(figsize=(30,7))
plt.subplot(1,4,1)

# col_sum = np.sum(gaussian, axis=0)
plt.imshow(col_sum)
h = 325
v = 330
plt.axhline(h, color='r')
plt.axvline(v, color='r')

plt.subplot(1,4,2)
plt.plot(gaussian[:, v, h])
plt.title('Intensity across Z')


plt.figure(figsize=(30,7))
plt.subplot(1,4,1)

# col_sum = np.sum(gaussian, axis=0)
plt.imshow(col_sum)
h = 280
v = 650
plt.axhline(h, color='r')
plt.axvline(v, color='r')

plt.subplot(1,4,2)
plt.plot(gaussian[:, v, h])
plt.title('Intensity across Z')

###
plt.figure(figsize=(30,7))
plt.subplot(1,4,1)

plt.imshow(col_sum)
h = 0
v = 0
plt.axhline(h, color='r')
plt.axvline(v, color='r')

plt.subplot(1,4,2)
plt.plot(gaussian[:, v, h])
plt.title('Intensity across Z')
# Out:
# Text(0.5, 1.0, 'Intensity across Z')

# %%
peaks_l = []
for v in range(gaussian.shape[1]):
    for h in range(gaussian.shape[2]):
        peaks = find_peaks(gaussian[:, v, h])
        if len(peaks[0]) > 0:
            peaks_l.append(peaks[0][0])
        else: 
            peaks_l.append(0)
        
        print(peaks)
        
        break
        
        
peaks = np.array(peaks_l)
peaks = np.reshape(peaks, (gaussian.shape[1], gaussian.shape[2]))
# Out:
# (array([395, 453, 456, 476], dtype=int64), {})
# (array([395, 453, 456, 476], dtype=int64), {})
# (array([395, 453, 456, 476], dtype=int64), {})
# (array([395, 457, 477], dtype=int64), {})
# (array([395, 457, 477], dtype=int64), {})
# (array([395, 478], dtype=int64), {})
# (array([395, 478], dtype=int64), {})
# (array([395, 478], dtype=int64), {})
# (array([395, 478], dtype=int64), {})
# (array([395, 477], dtype=int64), {})
# (array([395, 477], dtype=int64), {})
# (array([395, 476], dtype=int64), {})
# (array([395, 476], dtype=int64), {})
# (array([395, 475], dtype=int64), {})
# (array([395, 472], dtype=int64), {})
# (array([395, 470], dtype=int64), {})
# (array([395, 469], dtype=int64), {})
# (array([395, 468], dtype=int64), {})
# (array([395, 468], dtype=int64), {})
# (array([395, 467], dtype=int64), {})
# (array([395, 467], dtype=int64), {})
# (array([395, 466, 489], dtype=int64), {})
# (array([395, 466, 490], dtype=int64), {})
# (array([395, 465, 480, 491], dtype=int64), {})
# (array([395, 465, 480, 491], dtype=int64), {})
# (array([395, 465, 481, 491], dtype=int64), {})
# (array([395, 465, 481, 491], dtype=int64), {})
# (array([395, 465, 481, 491], dtype=int64), {})
# (array([395, 458, 465, 495], dtype=int64), {})
# (array([395, 457, 471, 496], dtype=int64), {})
# (array([395, 456, 471, 496], dtype=int64), {})
# (array([395, 456, 471, 496], dtype=int64), {})
# (array([395, 456, 471, 492], dtype=int64), {})
# (array([395, 456, 470, 492], dtype=int64), {})
# (array([395, 456, 470, 492], dtype=int64), {})
# (array([395, 456, 470, 492], dtype=int64), {})
# (array([395, 456, 469, 492], dtype=int64), {})
# (array([395, 456, 469, 492], dtype=int64), {})
# (array([395, 457, 469, 491], dtype=int64), {})
# (array([395, 457, 469, 491], dtype=int64), {})
# (array([395, 458, 469, 490], dtype=int64), {})
# (array([395, 458, 469, 482, 489], dtype=int64), {})
# (array([395, 460, 470, 481, 488], dtype=int64), {})
# (array([395, 461, 470, 481, 487], dtype=int64), {})
# (array([395, 470, 480], dtype=int64), {})
# (array([395, 469, 480], dtype=int64), {})
# (array([395, 469, 479], dtype=int64), {})
# (array([395, 469, 478], dtype=int64), {})
# (array([395, 469, 477], dtype=int64), {})
# (array([395, 468], dtype=int64), {})
# (array([395, 468], dtype=int64), {})
# (array([395, 468], dtype=int64), {})
# (array([395, 468], dtype=int64), {})
# (array([395, 468], dtype=int64), {})
# (array([395, 468], dtype=int64), {})
# (array([395, 469], dtype=int64), {})
# (array([395, 470], dtype=int64), {})
# (array([395, 471], dtype=int64), {})
# (array([395, 471], dtype=int64), {})
# (array([395, 471], dtype=int64), {})
# (array([395, 471], dtype=int64), {})
# (array([395, 472, 485], dtype=int64), {})
# (array([395, 472, 485], dtype=int64), {})
# (array([395, 471, 486], dtype=int64), {})
# (array([395, 471, 486], dtype=int64), {})
# (array([395, 463, 470, 486], dtype=int64), {})
# (array([395, 462, 468, 487], dtype=int64), {})
# (array([395, 462, 467, 487], dtype=int64), {})
# (array([395, 462, 488], dtype=int64), {})
# (array([395, 462, 488], dtype=int64), {})
# (array([395, 462, 475, 488], dtype=int64), {})
# (array([395, 462, 476, 489], dtype=int64), {})
# (array([395, 463, 476, 489], dtype=int64), {})
# (array([395, 464, 476, 489], dtype=int64), {})
# (array([395, 464, 476, 490], dtype=int64), {})
# (array([395, 465, 476, 492], dtype=int64), {})
# (array([395, 466, 477, 492], dtype=int64), {})
# (array([395, 478, 493], dtype=int64), {})
# (array([395, 478, 493], dtype=int64), {})
# (array([395, 479, 492], dtype=int64), {})
# (array([395, 480, 492], dtype=int64), {})
# (array([395, 460, 480], dtype=int64), {})
# (array([395, 460, 480], dtype=int64), {})
# (array([395, 460, 481], dtype=int64), {})
# (array([395, 460, 482], dtype=int64), {})
# (array([395, 461, 483], dtype=int64), {})
# (array([395, 461, 483], dtype=int64), {})
# (array([395, 462, 484], dtype=int64), {})
# (array([395, 463, 488], dtype=int64), {})
# (array([395, 464, 489], dtype=int64), {})
# (array([395, 465, 489], dtype=int64), {})
# (array([395, 466, 489], dtype=int64), {})
# (array([396, 467, 489], dtype=int64), {})
# (array([396, 468, 489], dtype=int64), {})
# (array([396, 470, 489, 493], dtype=int64), {})
# (array([396, 494], dtype=int64), {})
# (array([396, 494], dtype=int64), {})
# (array([396, 483, 494], dtype=int64), {})
# (array([396, 476, 494], dtype=int64), {})
# (array([396, 476, 494], dtype=int64), {})
# (array([396, 477, 494], dtype=int64), {})
# (array([396, 477, 493], dtype=int64), {})
# (array([396, 477, 493], dtype=int64), {})
# (array([396, 477, 493], dtype=int64), {})
# (array([396, 478], dtype=int64), {})
# (array([396, 478], dtype=int64), {})
# (array([396, 478], dtype=int64), {})
# (array([396, 478], dtype=int64), {})
# (array([396, 479], dtype=int64), {})
# (array([396, 479], dtype=int64), {})
# (array([396, 479], dtype=int64), {})
# (array([396, 479], dtype=int64), {})
# (array([396, 450, 479], dtype=int64), {})
# (array([396, 450, 480], dtype=int64), {})
# (array([396, 449, 480], dtype=int64), {})
# (array([396, 449, 480], dtype=int64), {})
# (array([396, 449, 481], dtype=int64), {})
# (array([396, 448, 481], dtype=int64), {})
# (array([396, 448, 481], dtype=int64), {})
# (array([396, 448, 482], dtype=int64), {})
# (array([396, 448, 482], dtype=int64), {})
# (array([396, 448, 483], dtype=int64), {})
# (array([396, 448, 483], dtype=int64), {})
# (array([396, 448, 484], dtype=int64), {})
# (array([396, 449, 485], dtype=int64), {})
# (array([396, 449, 479, 485], dtype=int64), {})
# (array([396, 449, 479, 486], dtype=int64), {})
# (array([396, 450, 478, 486], dtype=int64), {})
# (array([396, 452, 486], dtype=int64), {})
# (array([396, 485], dtype=int64), {})
# (array([396, 485], dtype=int64), {})
# (array([396, 463, 485], dtype=int64), {})
# (array([396, 462, 485], dtype=int64), {})
# (array([396, 461, 485], dtype=int64), {})
# (array([396, 459, 485], dtype=int64), {})
# (array([396, 457, 485], dtype=int64), {})
# (array([396, 456, 485], dtype=int64), {})
# (array([396, 455, 477, 485], dtype=int64), {})
# (array([396, 455, 476, 485], dtype=int64), {})
# (array([396, 454, 476, 485], dtype=int64), {})
# (array([396, 454, 476, 484], dtype=int64), {})
# (array([396, 454, 476, 484], dtype=int64), {})
# (array([396, 453, 475], dtype=int64), {})
# (array([396, 453, 472], dtype=int64), {})
# (array([396, 452], dtype=int64), {})
# (array([396, 452], dtype=int64), {})
# (array([396, 452, 489], dtype=int64), {})
# (array([396, 452, 489], dtype=int64), {})
# (array([396, 452, 489], dtype=int64), {})
# (array([396, 452, 488], dtype=int64), {})
# (array([396, 451, 487], dtype=int64), {})
# (array([396, 451, 487], dtype=int64), {})
# (array([396, 451], dtype=int64), {})
# (array([396, 451], dtype=int64), {})
# (array([396, 451], dtype=int64), {})
# (array([396, 452], dtype=int64), {})
# (array([396, 452], dtype=int64), {})
# (array([396, 452], dtype=int64), {})
# (array([396, 452], dtype=int64), {})
# (array([396, 453], dtype=int64), {})
# (array([396, 454], dtype=int64), {})
# (array([396, 454], dtype=int64), {})
# (array([396, 455, 480], dtype=int64), {})
# (array([396, 455, 480], dtype=int64), {})
# (array([396, 456, 481], dtype=int64), {})
# (array([396, 457, 481], dtype=int64), {})
# (array([396, 458, 481], dtype=int64), {})
# (array([396, 459, 474, 484], dtype=int64), {})
# (array([396, 463, 472, 485], dtype=int64), {})
# (array([396, 465, 486], dtype=int64), {})
# (array([396, 466, 487], dtype=int64), {})
# (array([396, 466, 488], dtype=int64), {})
# (array([396, 466, 488], dtype=int64), {})
# (array([396, 466, 488], dtype=int64), {})
# (array([396, 466, 488], dtype=int64), {})
# (array([396, 467, 489], dtype=int64), {})
# (array([396, 469, 489], dtype=int64), {})
# (array([396, 471, 489], dtype=int64), {})
# (array([396, 472, 488], dtype=int64), {})
# (array([396, 472, 486, 495], dtype=int64), {})
# (array([396, 472, 485, 497], dtype=int64), {})
# (array([396, 464, 474, 484, 498], dtype=int64), {})
# (array([396, 464, 474, 483, 499], dtype=int64), {})
# (array([396, 464, 472, 483, 501], dtype=int64), {})
# (array([396, 463, 472, 482, 502], dtype=int64), {})
# (array([396, 463, 472, 482, 503], dtype=int64), {})
# (array([396, 462, 472, 482, 503], dtype=int64), {})
# (array([396, 462, 472, 482, 503], dtype=int64), {})
# (array([396, 462, 472, 481, 503], dtype=int64), {})
# (array([396, 467, 474, 480, 503], dtype=int64), {})
# (array([396, 467, 475, 480, 486, 503], dtype=int64), {})
# (array([396, 460, 466, 480, 487, 504], dtype=int64), {})
# (array([396, 459, 466, 479, 488, 504, 508, 515], dtype=int64), {})
# (array([396, 459, 465, 479, 488, 509], dtype=int64), {})
# (array([396, 459, 479, 489, 509], dtype=int64), {})
# (array([396, 459, 478, 489, 509], dtype=int64), {})
# (array([396, 459, 476, 489, 509], dtype=int64), {})
# (array([396, 411, 459, 475, 490, 509], dtype=int64), {})
# (array([396, 411, 459, 475, 490, 509, 517], dtype=int64), {})
# (array([396, 411, 459, 474, 491, 509, 517], dtype=int64), {})
# (array([396, 410, 460, 474, 491, 509, 517], dtype=int64), {})
# (array([396, 410, 461, 474, 492, 509], dtype=int64), {})
# (array([396, 409, 461, 492], dtype=int64), {})
# (array([396, 409, 461, 492], dtype=int64), {})
# (array([396, 410, 460, 493], dtype=int64), {})
# (array([396, 459, 493], dtype=int64), {})
# (array([396, 459, 494], dtype=int64), {})
# (array([396, 458, 494], dtype=int64), {})
# (array([396, 458, 494], dtype=int64), {})
# (array([396, 458, 495], dtype=int64), {})
# (array([396, 458, 495], dtype=int64), {})
# (array([396, 458, 495], dtype=int64), {})
# (array([396, 459, 495], dtype=int64), {})
# (array([396, 460, 494], dtype=int64), {})
# (array([396, 462, 494], dtype=int64), {})
# (array([396, 463, 493], dtype=int64), {})
# (array([396, 464, 492], dtype=int64), {})
# (array([396, 492], dtype=int64), {})
# (array([396, 492], dtype=int64), {})
# (array([396, 492], dtype=int64), {})
# (array([396, 466, 492], dtype=int64), {})
# (array([396, 465, 481, 491], dtype=int64), {})
# (array([396, 464, 480, 491], dtype=int64), {})
# (array([396, 464, 479, 490], dtype=int64), {})
# (array([396, 463, 489], dtype=int64), {})
# (array([396, 463, 488], dtype=int64), {})
# (array([396, 463, 486], dtype=int64), {})
# (array([396, 463, 485], dtype=int64), {})
# (array([396, 462, 484], dtype=int64), {})
# (array([396, 462, 484], dtype=int64), {})
# (array([396, 462, 483], dtype=int64), {})
# (array([396, 461, 482], dtype=int64), {})
# (array([396, 458, 468], dtype=int64), {})
# (array([396, 457, 470], dtype=int64), {})
# (array([396, 456, 471], dtype=int64), {})
# (array([396, 456, 473], dtype=int64), {})
# (array([396, 456, 475], dtype=int64), {})
# (array([396, 455, 476], dtype=int64), {})
# (array([396, 455, 476], dtype=int64), {})
# (array([396, 455, 477], dtype=int64), {})
# (array([396, 455, 477], dtype=int64), {})
# (array([396, 455, 477], dtype=int64), {})
# (array([396, 455, 476, 490], dtype=int64), {})
# (array([396, 456, 476, 491], dtype=int64), {})
# (array([396, 475, 492], dtype=int64), {})
# (array([396, 475, 493], dtype=int64), {})
# (array([396, 474, 494], dtype=int64), {})
# (array([396, 473, 494], dtype=int64), {})
# (array([396, 472, 494], dtype=int64), {})
# (array([396, 471, 495], dtype=int64), {})
# (array([396, 472, 495], dtype=int64), {})
# (array([396, 473, 495], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 496], dtype=int64), {})
# (array([396, 496], dtype=int64), {})
# (array([396, 483, 496], dtype=int64), {})
# (array([396, 483, 496], dtype=int64), {})
# (array([396, 483, 497], dtype=int64), {})
# (array([396, 483, 497], dtype=int64), {})
# (array([396, 484, 497, 503], dtype=int64), {})
# (array([396, 498, 504], dtype=int64), {})
# (array([396, 505], dtype=int64), {})
# (array([396, 505], dtype=int64), {})
# (array([396, 506], dtype=int64), {})
# (array([396, 481, 506], dtype=int64), {})
# (array([396, 480, 506], dtype=int64), {})
# (array([396, 480, 495, 507], dtype=int64), {})
# (array([396, 480, 493, 507], dtype=int64), {})
# (array([397, 480, 507], dtype=int64), {})
# (array([397, 481, 507], dtype=int64), {})
# (array([397, 481, 507], dtype=int64), {})
# (array([397, 481, 507], dtype=int64), {})
# (array([482, 507], dtype=int64), {})
# (array([482, 507], dtype=int64), {})
# (array([481, 507], dtype=int64), {})
# (array([481, 507], dtype=int64), {})
# (array([481, 508], dtype=int64), {})
# (array([481, 508], dtype=int64), {})
# (array([481, 508], dtype=int64), {})
# (array([481, 508], dtype=int64), {})
# (array([481, 508], dtype=int64), {})
# (array([482, 508], dtype=int64), {})
# (array([482, 508], dtype=int64), {})
# (array([463, 482, 508], dtype=int64), {})
# (array([462, 482, 508], dtype=int64), {})
# (array([462, 482, 508], dtype=int64), {})
# (array([462, 482, 508], dtype=int64), {})
# (array([462, 483, 508], dtype=int64), {})
# (array([463, 483, 507], dtype=int64), {})
# (array([484, 507], dtype=int64), {})
# (array([484, 506], dtype=int64), {})
# (array([398, 485, 506], dtype=int64), {})
# (array([398, 485, 504], dtype=int64), {})
# (array([397, 486, 503], dtype=int64), {})
# (array([397, 487, 501], dtype=int64), {})
# (array([397, 487, 500], dtype=int64), {})
# (array([397, 488], dtype=int64), {})
# (array([397, 488], dtype=int64), {})
# (array([396, 489], dtype=int64), {})
# (array([396, 444, 488], dtype=int64), {})
# (array([396, 444, 488], dtype=int64), {})
# (array([396, 443, 488], dtype=int64), {})
# (array([396, 441, 487], dtype=int64), {})
# (array([397, 441, 487], dtype=int64), {})
# (array([397, 441, 487], dtype=int64), {})
# (array([397, 441, 486], dtype=int64), {})
# (array([397, 442, 486], dtype=int64), {})
# (array([397, 443, 485, 502], dtype=int64), {})
# (array([397, 485, 503], dtype=int64), {})
# (array([396, 484, 503], dtype=int64), {})
# (array([396, 484, 503], dtype=int64), {})
# (array([396, 484, 503], dtype=int64), {})
# (array([396, 484], dtype=int64), {})
# (array([396, 484], dtype=int64), {})
# (array([396, 485], dtype=int64), {})
# (array([396, 490], dtype=int64), {})
# (array([396, 491], dtype=int64), {})
# (array([396, 491], dtype=int64), {})
# (array([396, 492], dtype=int64), {})
# (array([396, 492], dtype=int64), {})
# (array([396, 493], dtype=int64), {})
# (array([396, 463, 493], dtype=int64), {})
# (array([396, 461, 494], dtype=int64), {})
# (array([396, 460, 495], dtype=int64), {})
# (array([396, 459, 495], dtype=int64), {})
# (array([396, 458, 496], dtype=int64), {})
# (array([396, 458, 496], dtype=int64), {})
# (array([396, 458, 496], dtype=int64), {})
# (array([396, 461, 497], dtype=int64), {})
# (array([396, 497], dtype=int64), {})
# (array([396, 497], dtype=int64), {})
# (array([397, 498], dtype=int64), {})
# (array([397, 498], dtype=int64), {})
# (array([397, 498], dtype=int64), {})
# (array([397, 499], dtype=int64), {})
# (array([396, 499], dtype=int64), {})
# (array([396, 500], dtype=int64), {})
# (array([396, 501], dtype=int64), {})
# (array([396, 501], dtype=int64), {})
# (array([396, 501], dtype=int64), {})
# (array([396, 501], dtype=int64), {})
# (array([396, 501], dtype=int64), {})
# (array([396, 500], dtype=int64), {})
# (array([396, 499], dtype=int64), {})
# (array([396, 498], dtype=int64), {})
# (array([396, 497], dtype=int64), {})
# (array([396, 496], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 494], dtype=int64), {})
# (array([396, 493], dtype=int64), {})
# (array([396, 492], dtype=int64), {})
# (array([396, 491], dtype=int64), {})
# (array([396, 489], dtype=int64), {})
# (array([396, 488], dtype=int64), {})
# (array([396, 486], dtype=int64), {})
# (array([396, 484], dtype=int64), {})
# (array([396, 482], dtype=int64), {})
# (array([396, 481], dtype=int64), {})
# (array([396, 480], dtype=int64), {})
# (array([396, 479], dtype=int64), {})
# (array([396, 479], dtype=int64), {})
# (array([396, 478], dtype=int64), {})
# (array([396, 477], dtype=int64), {})
# (array([396, 477], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 475], dtype=int64), {})
# (array([396, 475], dtype=int64), {})
# (array([396, 475], dtype=int64), {})
# (array([396, 475], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([397, 476], dtype=int64), {})
# (array([397, 477], dtype=int64), {})
# (array([397, 477], dtype=int64), {})
# (array([396, 477], dtype=int64), {})
# (array([396, 478], dtype=int64), {})
# (array([396, 478], dtype=int64), {})
# (array([396, 479], dtype=int64), {})
# (array([396, 479], dtype=int64), {})
# (array([396, 480], dtype=int64), {})
# (array([396, 480], dtype=int64), {})
# (array([396, 480], dtype=int64), {})
# (array([396, 481, 489], dtype=int64), {})
# (array([396, 490], dtype=int64), {})
# (array([396, 490], dtype=int64), {})
# (array([396, 491, 505], dtype=int64), {})
# (array([396, 491, 506], dtype=int64), {})
# (array([396, 492, 507], dtype=int64), {})
# (array([396, 492, 507], dtype=int64), {})
# (array([396, 507], dtype=int64), {})
# (array([397, 469, 507], dtype=int64), {})
# (array([397, 467, 507], dtype=int64), {})
# (array([397, 466, 507], dtype=int64), {})
# (array([397, 465, 507], dtype=int64), {})
# (array([397, 465, 499, 507], dtype=int64), {})
# (array([397, 464, 499, 507], dtype=int64), {})
# (array([396, 464, 499, 507], dtype=int64), {})
# (array([396, 463, 499, 507], dtype=int64), {})
# (array([396, 462, 499, 506], dtype=int64), {})
# (array([396, 461, 499, 506], dtype=int64), {})
# (array([396, 460, 506], dtype=int64), {})
# (array([397, 460, 506], dtype=int64), {})
# (array([397, 459, 506], dtype=int64), {})
# (array([397, 459, 505], dtype=int64), {})
# (array([397, 458, 505], dtype=int64), {})
# (array([397, 458, 472, 505], dtype=int64), {})
# (array([397, 458, 505], dtype=int64), {})
# (array([397, 458, 505], dtype=int64), {})
# (array([397, 458, 499, 505], dtype=int64), {})
# (array([397, 458, 499, 506], dtype=int64), {})
# (array([397, 458, 472, 499, 507], dtype=int64), {})
# (array([397, 458, 471, 483, 508], dtype=int64), {})
# (array([397, 458, 471, 483, 508], dtype=int64), {})
# (array([397, 458, 470, 482, 508], dtype=int64), {})
# (array([397, 458, 470, 482, 506], dtype=int64), {})
# (array([397, 458, 471, 482, 504], dtype=int64), {})
# (array([397, 458, 483, 503], dtype=int64), {})
# (array([397, 458, 483, 502], dtype=int64), {})
# (array([397, 459, 484, 501], dtype=int64), {})
# (array([397, 459, 485, 500], dtype=int64), {})
# (array([397, 459, 500], dtype=int64), {})
# (array([397, 460, 498], dtype=int64), {})
# (array([397, 461, 497], dtype=int64), {})
# (array([397, 462, 497], dtype=int64), {})
# (array([396, 497], dtype=int64), {})
# (array([396, 497], dtype=int64), {})
# (array([396, 496], dtype=int64), {})
# (array([396, 496], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 494], dtype=int64), {})
# (array([396, 493], dtype=int64), {})
# (array([396, 492], dtype=int64), {})
# (array([396, 491], dtype=int64), {})
# (array([396, 490], dtype=int64), {})
# (array([396, 490], dtype=int64), {})
# (array([396, 474, 485, 489], dtype=int64), {})
# (array([396, 473, 483], dtype=int64), {})
# (array([396, 472], dtype=int64), {})
# (array([396, 472], dtype=int64), {})
# (array([396, 472, 485], dtype=int64), {})
# (array([397, 471, 486], dtype=int64), {})
# (array([397, 471, 486], dtype=int64), {})
# (array([397, 470, 486], dtype=int64), {})
# (array([397, 470, 486], dtype=int64), {})
# (array([397, 470, 487], dtype=int64), {})
# (array([397, 469, 487], dtype=int64), {})
# (array([397, 469, 488], dtype=int64), {})
# (array([397, 469, 488], dtype=int64), {})
# (array([397, 469, 488], dtype=int64), {})
# (array([397, 469, 488], dtype=int64), {})
# (array([397, 469, 488], dtype=int64), {})
# (array([397, 469, 488], dtype=int64), {})
# (array([397, 469, 488], dtype=int64), {})
# (array([397, 469], dtype=int64), {})
# (array([397, 469, 482], dtype=int64), {})
# (array([397, 469, 482], dtype=int64), {})
# (array([397, 469, 482], dtype=int64), {})
# (array([397, 470, 482, 487, 501], dtype=int64), {})
# (array([397, 470, 483, 488, 501], dtype=int64), {})
# (array([397, 458, 471, 488, 502], dtype=int64), {})
# (array([398, 458, 472, 488, 503], dtype=int64), {})
# (array([397, 457, 487, 503], dtype=int64), {})
# (array([397, 457, 483, 487, 504], dtype=int64), {})
# (array([397, 457, 483, 504], dtype=int64), {})
# (array([397, 457, 482, 504], dtype=int64), {})
# (array([397, 457, 482, 504], dtype=int64), {})
# (array([397, 457, 481, 504], dtype=int64), {})
# (array([397, 457, 481, 504], dtype=int64), {})
# (array([397, 457, 481, 504], dtype=int64), {})
# (array([397, 457, 480, 503], dtype=int64), {})
# (array([397, 457, 480, 503], dtype=int64), {})
# (array([397, 457, 480, 503], dtype=int64), {})
# (array([397, 457, 480, 502], dtype=int64), {})
# (array([397, 458, 480, 502], dtype=int64), {})
# (array([397, 458, 480, 501], dtype=int64), {})
# (array([397, 458, 481, 501], dtype=int64), {})
# (array([397, 459, 481, 501], dtype=int64), {})
# (array([397, 459, 474, 480, 500], dtype=int64), {})
# (array([397, 472, 480, 500], dtype=int64), {})
# (array([397, 471, 499], dtype=int64), {})
# (array([397, 470, 498], dtype=int64), {})
# (array([397, 469, 486, 497], dtype=int64), {})
# (array([397, 468, 487, 497], dtype=int64), {})
# (array([397, 467, 496], dtype=int64), {})
# (array([397, 466, 496], dtype=int64), {})
# (array([397, 466, 496], dtype=int64), {})
# (array([397, 465, 496], dtype=int64), {})
# (array([397, 465, 496], dtype=int64), {})
# (array([397, 464, 495], dtype=int64), {})
# (array([397, 464, 495], dtype=int64), {})
# (array([397, 464, 494], dtype=int64), {})
# (array([397, 464, 493], dtype=int64), {})
# (array([397, 464, 493], dtype=int64), {})
# (array([397, 464, 492], dtype=int64), {})
# (array([398, 465, 492], dtype=int64), {})
# (array([398, 465, 493], dtype=int64), {})
# (array([398, 465, 493], dtype=int64), {})
# (array([397, 465, 493], dtype=int64), {})
# (array([397, 466, 493], dtype=int64), {})
# (array([397, 466, 494], dtype=int64), {})
# (array([397, 466, 494], dtype=int64), {})
# (array([397, 474, 494], dtype=int64), {})
# (array([397, 476, 495], dtype=int64), {})
# (array([398, 478, 495], dtype=int64), {})
# (array([397, 479, 495], dtype=int64), {})
# (array([397, 484, 495], dtype=int64), {})
# (array([397, 486], dtype=int64), {})
# (array([397, 487], dtype=int64), {})
# (array([397, 488], dtype=int64), {})
# (array([397, 489], dtype=int64), {})
# (array([490], dtype=int64), {})
# (array([490], dtype=int64), {})
# (array([491], dtype=int64), {})
# (array([492], dtype=int64), {})
# (array([493], dtype=int64), {})
# (array([494], dtype=int64), {})
# (array([495], dtype=int64), {})
# (array([496], dtype=int64), {})
# (array([497], dtype=int64), {})
# (array([497], dtype=int64), {})
# (array([498], dtype=int64), {})
# (array([498], dtype=int64), {})
# (array([497], dtype=int64), {})
# (array([496], dtype=int64), {})
# (array([461, 495], dtype=int64), {})
# (array([460, 494], dtype=int64), {})
# (array([460, 494], dtype=int64), {})
# (array([459, 494], dtype=int64), {})
# (array([459, 493], dtype=int64), {})
# (array([458, 493], dtype=int64), {})
# (array([458, 493], dtype=int64), {})
# (array([457, 493], dtype=int64), {})
# (array([457, 493], dtype=int64), {})
# (array([456, 493], dtype=int64), {})
# (array([455, 492], dtype=int64), {})
# (array([455, 491, 505], dtype=int64), {})
# (array([455, 490, 506], dtype=int64), {})
# (array([454, 490, 506], dtype=int64), {})
# (array([454, 489, 507], dtype=int64), {})
# (array([453, 488, 507], dtype=int64), {})
# (array([453, 487, 508], dtype=int64), {})
# (array([453, 486, 508], dtype=int64), {})
# (array([453, 485, 508], dtype=int64), {})
# (array([453, 478, 485, 508], dtype=int64), {})
# (array([453, 477, 484, 507], dtype=int64), {})
# (array([453, 476, 483, 507], dtype=int64), {})
# (array([453, 475, 507], dtype=int64), {})
# (array([453, 475, 506], dtype=int64), {})
# (array([454, 475, 504], dtype=int64), {})
# (array([454, 475, 504], dtype=int64), {})
# (array([455, 476, 503], dtype=int64), {})
# (array([456, 476, 503], dtype=int64), {})
# (array([456, 477, 502], dtype=int64), {})
# (array([456, 477, 501], dtype=int64), {})
# (array([456, 477], dtype=int64), {})
# (array([456, 477], dtype=int64), {})
# (array([457, 482], dtype=int64), {})
# (array([458, 482], dtype=int64), {})
# (array([458, 482], dtype=int64), {})
# (array([460, 482], dtype=int64), {})
# (array([461, 482], dtype=int64), {})
# (array([462, 481], dtype=int64), {})
# (array([464, 481], dtype=int64), {})
# (array([465, 481], dtype=int64), {})
# (array([397, 465, 481], dtype=int64), {})
# (array([397, 466, 481], dtype=int64), {})
# (array([397, 467, 482], dtype=int64), {})
# (array([397, 470, 482], dtype=int64), {})
# (array([397, 482], dtype=int64), {})
# (array([397, 482], dtype=int64), {})
# (array([397, 482], dtype=int64), {})
# (array([397, 481], dtype=int64), {})
# (array([397, 481, 490], dtype=int64), {})
# (array([397, 474, 481, 491], dtype=int64), {})
# (array([396, 472, 481, 492], dtype=int64), {})
# (array([396, 469, 493], dtype=int64), {})
# (array([396, 466, 493], dtype=int64), {})
# (array([396, 465, 493], dtype=int64), {})
# (array([396, 465, 491, 496], dtype=int64), {})
# (array([396, 464, 498], dtype=int64), {})
# (array([396, 464, 500], dtype=int64), {})
# (array([396, 464, 501], dtype=int64), {})
# (array([396, 464, 502], dtype=int64), {})
# (array([396, 463, 502], dtype=int64), {})
# (array([396, 463, 503], dtype=int64), {})
# (array([396, 463, 503], dtype=int64), {})
# (array([396, 463, 503], dtype=int64), {})
# (array([396, 463, 504], dtype=int64), {})
# (array([396, 463, 504], dtype=int64), {})
# (array([397, 463, 505], dtype=int64), {})
# (array([397, 463, 505], dtype=int64), {})
# (array([397, 463, 504], dtype=int64), {})
# (array([397, 463, 498], dtype=int64), {})
# (array([397, 464, 497], dtype=int64), {})
# (array([397, 464, 497], dtype=int64), {})
# (array([397, 464, 496], dtype=int64), {})
# (array([397, 465, 496], dtype=int64), {})
# (array([397, 465, 496], dtype=int64), {})
# (array([397, 466, 496], dtype=int64), {})
# (array([397, 467, 494], dtype=int64), {})
# (array([396, 469], dtype=int64), {})
# (array([396, 477], dtype=int64), {})
# (array([396, 477], dtype=int64), {})
# (array([396, 477], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 475], dtype=int64), {})
# (array([396, 474], dtype=int64), {})
# (array([396, 472], dtype=int64), {})
# (array([396, 469], dtype=int64), {})
# (array([396, 468, 498], dtype=int64), {})
# (array([396, 468, 500], dtype=int64), {})
# (array([396, 467, 501], dtype=int64), {})
# (array([396, 466, 501], dtype=int64), {})
# (array([396, 465, 502], dtype=int64), {})
# (array([396, 464, 503], dtype=int64), {})
# (array([396, 464, 503], dtype=int64), {})
# (array([396, 463, 504], dtype=int64), {})
# (array([396, 462, 504], dtype=int64), {})
# (array([396, 462, 505], dtype=int64), {})
# (array([396, 462, 505], dtype=int64), {})
# (array([396, 462, 505], dtype=int64), {})
# (array([396, 462, 505], dtype=int64), {})
# (array([396, 462, 505], dtype=int64), {})
# (array([396, 461, 505], dtype=int64), {})
# (array([396, 462, 506], dtype=int64), {})
# (array([396, 462, 506], dtype=int64), {})
# (array([396, 462, 505], dtype=int64), {})
# (array([396, 462, 505], dtype=int64), {})
# (array([396, 462, 505], dtype=int64), {})
# (array([396, 462, 504], dtype=int64), {})
# (array([396, 463, 503], dtype=int64), {})
# (array([396, 463, 472], dtype=int64), {})
# (array([396, 464, 472], dtype=int64), {})
# (array([396, 465, 472], dtype=int64), {})
# (array([396, 472], dtype=int64), {})
# (array([396, 472], dtype=int64), {})
# (array([396, 472], dtype=int64), {})
# (array([396, 472], dtype=int64), {})
# (array([396, 472], dtype=int64), {})
# (array([396, 474], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 476], dtype=int64), {})
# (array([396, 476, 489], dtype=int64), {})
# (array([396, 476, 491], dtype=int64), {})
# (array([396, 474, 492], dtype=int64), {})
# (array([396, 474, 493], dtype=int64), {})
# (array([396, 473, 494], dtype=int64), {})
# (array([396, 473, 495], dtype=int64), {})
# (array([396, 473, 496], dtype=int64), {})
# (array([396, 473, 497], dtype=int64), {})
# (array([396, 473, 498], dtype=int64), {})
# (array([396, 473, 499], dtype=int64), {})
# (array([396, 472, 500], dtype=int64), {})
# (array([396, 472, 500], dtype=int64), {})
# (array([396, 471, 499], dtype=int64), {})
# (array([396, 471, 499], dtype=int64), {})
# (array([396, 471, 482, 499], dtype=int64), {})
# (array([396, 470, 482, 498], dtype=int64), {})
# (array([396, 471, 483, 498], dtype=int64), {})
# (array([396, 471, 483, 498], dtype=int64), {})
# (array([396, 471, 484, 497], dtype=int64), {})
# (array([396, 473, 496], dtype=int64), {})
# (array([396, 495], dtype=int64), {})
# (array([396, 494], dtype=int64), {})
# (array([396, 492], dtype=int64), {})
# (array([396, 491], dtype=int64), {})
# (array([396, 491], dtype=int64), {})
# (array([396, 461, 490], dtype=int64), {})
# (array([396, 460, 490], dtype=int64), {})
# (array([396, 461, 490], dtype=int64), {})
# (array([396, 461, 490], dtype=int64), {})
# (array([396, 461, 490], dtype=int64), {})
# (array([396, 490], dtype=int64), {})
# (array([396, 453, 491], dtype=int64), {})
# (array([396, 452, 492], dtype=int64), {})
# (array([396, 452, 493], dtype=int64), {})
# (array([396, 451, 493], dtype=int64), {})
# (array([396, 451, 493], dtype=int64), {})
# (array([396, 450, 493], dtype=int64), {})
# (array([396, 450, 492], dtype=int64), {})
# (array([396, 449, 491], dtype=int64), {})
# (array([396, 449, 489], dtype=int64), {})
# (array([396, 449, 489], dtype=int64), {})
# (array([396, 449, 489], dtype=int64), {})
# (array([396, 450, 489], dtype=int64), {})
# (array([396, 450, 489], dtype=int64), {})
# (array([396, 451, 490], dtype=int64), {})
# (array([396, 453, 490], dtype=int64), {})
# (array([396, 490], dtype=int64), {})
# (array([396, 481, 490], dtype=int64), {})
# (array([396, 480, 490], dtype=int64), {})
# (array([396, 479, 490], dtype=int64), {})
# (array([396, 449, 479, 490], dtype=int64), {})
# (array([396, 449, 478, 490], dtype=int64), {})
# (array([396, 478, 489], dtype=int64), {})
# (array([396, 477, 489], dtype=int64), {})
# (array([396, 477, 488, 507], dtype=int64), {})
# (array([396, 476, 488, 507], dtype=int64), {})
# (array([396, 475, 487, 508], dtype=int64), {})
# (array([396, 475, 508], dtype=int64), {})
# (array([396, 476, 508], dtype=int64), {})
# (array([396, 470, 476, 507], dtype=int64), {})
# (array([396, 468, 477, 507], dtype=int64), {})
# (array([396, 467, 477, 506], dtype=int64), {})
# (array([396, 467, 477, 506], dtype=int64), {})
# (array([396, 467, 506], dtype=int64), {})
# (array([396, 467, 506], dtype=int64), {})
# (array([396, 467, 506], dtype=int64), {})
# (array([396, 467, 486, 506], dtype=int64), {})
# (array([396, 468, 486, 507], dtype=int64), {})
# (array([396, 409, 469, 477, 485, 507], dtype=int64), {})
# (array([396, 409, 470, 478, 507], dtype=int64), {})
# (array([396, 409, 471, 479, 507], dtype=int64), {})
# (array([396, 472, 479, 506], dtype=int64), {})
# (array([396, 473, 480, 503], dtype=int64), {})
# (array([396, 474, 502], dtype=int64), {})
# (array([396, 417, 475, 502], dtype=int64), {})
# (array([396, 416, 475, 502], dtype=int64), {})
# (array([396, 416, 477, 502], dtype=int64), {})
# (array([396, 408, 416, 478, 501], dtype=int64), {})
# (array([396, 479, 501], dtype=int64), {})
# (array([396, 480, 496], dtype=int64), {})
# (array([396, 481, 495], dtype=int64), {})
# (array([396, 414, 483, 494, 520], dtype=int64), {})
# (array([396, 494, 522, 537], dtype=int64), {})
# (array([396, 494, 523, 537], dtype=int64), {})
# (array([396, 495, 513, 523, 536], dtype=int64), {})
# (array([396, 469, 496, 514, 523, 537], dtype=int64), {})
# (array([396, 410, 467, 498, 515, 524, 537], dtype=int64), {})
# (array([396, 409, 467, 500, 504, 524, 537], dtype=int64), {})
# (array([396, 409, 466, 524, 537], dtype=int64), {})
# (array([396, 409, 430, 459, 466, 523, 537], dtype=int64), {})
# (array([396, 410, 458, 466, 497, 522, 538], dtype=int64), {})
# (array([396, 410, 446, 459, 466, 497, 521, 538], dtype=int64), {})
# (array([396, 411, 446, 459, 466, 497, 520, 537], dtype=int64), {})
# (array([396, 412, 445, 460, 466, 496, 519, 537], dtype=int64), {})
# (array([396, 412, 445, 459, 466, 496, 519, 530], dtype=int64), {})
# (array([396, 413, 426, 445, 458, 467, 496, 519, 531, 548], dtype=int64), {})
# (array([396, 413, 425, 445, 457, 496, 518, 532], dtype=int64), {})
# (array([396, 406, 413, 425, 445, 457, 496, 518, 532], dtype=int64), {})
# (array([396, 406, 413, 425, 444, 456, 497, 518, 532], dtype=int64), {})
# (array([396, 406, 413, 425, 442, 456, 499, 518, 531], dtype=int64), {})
# (array([396, 406, 413, 425, 441, 457, 500, 518, 531], dtype=int64), {})
# (array([396, 406, 414, 425, 442, 457, 494, 501, 519, 536], dtype=int64), {})
# (array([396, 406, 426, 442, 457, 494, 502, 519, 537], dtype=int64), {})
# (array([396, 405, 415, 442, 457, 495, 503, 519, 537], dtype=int64), {})
# (array([396, 405, 415, 434, 443, 484, 504, 519, 537], dtype=int64), {})
# (array([396, 414, 434, 443, 483, 505, 513, 519, 537], dtype=int64), {})
# (array([396, 414, 434, 444, 483, 512, 537], dtype=int64), {})
# (array([396, 415, 434, 444, 483, 511, 536], dtype=int64), {})
# (array([396, 417, 434, 444, 482, 510, 536], dtype=int64), {})
# (array([396, 405, 434, 443, 482, 509, 535], dtype=int64), {})
# (array([396, 406, 443, 483, 508, 535], dtype=int64), {})
# (array([396, 406, 442, 508, 536], dtype=int64), {})
# (array([396, 406, 417, 441, 508, 532, 540], dtype=int64), {})
# (array([396, 406, 417, 428, 440, 508, 531, 540], dtype=int64), {})
# (array([396, 406, 417, 428, 440, 508, 530, 541], dtype=int64), {})
# (array([396, 407, 417, 429, 439, 456, 508, 529, 541], dtype=int64), {})
# (array([396, 407, 417, 439, 456, 508, 529, 541], dtype=int64), {})
# (array([396, 406, 417, 439, 455, 508, 529, 541], dtype=int64), {})
# (array([396, 406, 417, 438, 456, 508, 529, 541], dtype=int64), {})
# (array([396, 417, 438, 456, 508, 525, 530, 541], dtype=int64), {})
# (array([396, 418, 438, 456, 500, 508, 524, 530, 541], dtype=int64), {})
# (array([396, 418, 438, 508, 523, 531], dtype=int64), {})
# (array([396, 418, 439, 456, 509, 518, 531], dtype=int64), {})
# (array([396, 418, 446, 456, 508, 531], dtype=int64), {})
# (array([396, 410, 418, 431, 445, 456, 486, 507, 531], dtype=int64), {})
# (array([396, 410, 431, 445, 455, 485, 506, 515, 531], dtype=int64), {})
# (array([396, 409, 430, 445, 455, 484, 505, 515, 531], dtype=int64), {})
# (array([396, 409, 419, 429, 445, 455, 484, 505, 515, 531, 538], dtype=int64), {})
# (array([396, 409, 417, 428, 436, 445, 455, 485, 505, 515, 531, 538],
#       dtype=int64), {})
# (array([396, 416, 428, 436, 446, 455, 505, 515, 530], dtype=int64), {})
# (array([396, 416, 428, 456, 504, 515, 530], dtype=int64), {})
# (array([396, 416, 428, 457, 504, 515, 530], dtype=int64), {})
# (array([396, 416, 428, 458, 503, 515, 530], dtype=int64), {})
# (array([396, 416, 428, 503, 515, 529], dtype=int64), {})
# (array([396, 415, 428, 449, 459, 502, 515, 529], dtype=int64), {})
# (array([396, 415, 428, 448, 459, 502, 515, 521, 528], dtype=int64), {})
# (array([396, 415, 428, 448, 459, 501, 516, 522], dtype=int64), {})
# (array([396, 415, 429, 449, 459, 487, 501, 522], dtype=int64), {})
# (array([396, 415, 429, 449, 459, 487, 501, 522], dtype=int64), {})
# (array([396, 415, 429, 450, 459, 487, 501, 522], dtype=int64), {})
# (array([396, 415, 451, 459, 487, 501, 523], dtype=int64), {})
# (array([396, 414, 451, 459, 471, 486, 501, 523], dtype=int64), {})
# (array([396, 414, 451, 460, 470, 486, 501, 517, 524], dtype=int64), {})
# (array([396, 415, 451, 461, 478, 485, 517, 524], dtype=int64), {})
# (array([396, 415, 451, 462, 477, 485, 517, 525], dtype=int64), {})
# (array([396, 408, 415, 451, 462, 485, 524], dtype=int64), {})
# (array([396, 408, 415, 451, 463, 474, 484, 524], dtype=int64), {})
# (array([396, 407, 452, 463, 473, 485, 524], dtype=int64), {})
# (array([396, 407, 452, 464, 473, 484, 494, 524], dtype=int64), {})
# (array([396, 406, 466, 473, 484, 493, 524], dtype=int64), {})
# (array([396, 406, 467, 472, 483, 492, 523], dtype=int64), {})
# (array([396, 406, 468, 471, 492, 519], dtype=int64), {})
# (array([396, 406, 471, 492, 518], dtype=int64), {})
# (array([396, 406, 471, 518], dtype=int64), {})
# (array([396, 407, 472, 518], dtype=int64), {})
# (array([396, 472, 518], dtype=int64), {})
# (array([396, 472, 518], dtype=int64), {})
# (array([396, 472, 517], dtype=int64), {})
# (array([396, 472, 517], dtype=int64), {})
# (array([396, 472, 517], dtype=int64), {})
# (array([396, 472, 476, 517], dtype=int64), {})
# (array([396, 477, 517, 520], dtype=int64), {})
# (array([396, 477, 520], dtype=int64), {})
# (array([396, 478, 520], dtype=int64), {})
# (array([396, 479, 520], dtype=int64), {})
# (array([396, 482, 519], dtype=int64), {})
# (array([396, 484, 519], dtype=int64), {})
# (array([396, 484, 518], dtype=int64), {})
# (array([396, 485, 518], dtype=int64), {})
# (array([396, 485, 517], dtype=int64), {})
# (array([396, 485, 517], dtype=int64), {})
# (array([396, 486, 516], dtype=int64), {})
# (array([396, 486, 512], dtype=int64), {})
# (array([396, 486], dtype=int64), {})
# (array([396, 486], dtype=int64), {})
# (array([396, 486, 496, 501], dtype=int64), {})
# (array([396, 485, 496, 503], dtype=int64), {})
# (array([396, 485, 504], dtype=int64), {})
# (array([396, 484, 506], dtype=int64), {})
# (array([396, 484, 507], dtype=int64), {})
# (array([396, 483, 508], dtype=int64), {})
# (array([396, 482, 509], dtype=int64), {})
# (array([396, 481, 510], dtype=int64), {})
# (array([396, 480, 511], dtype=int64), {})
# (array([396, 479, 511], dtype=int64), {})
# (array([396, 479, 511], dtype=int64), {})
# (array([396, 479, 512], dtype=int64), {})
# (array([396, 480, 512], dtype=int64), {})
# (array([396, 480, 512], dtype=int64), {})
# (array([396, 479, 511], dtype=int64), {})
# (array([396, 479, 511], dtype=int64), {})
# (array([397, 479, 511], dtype=int64), {})
# (array([397, 479, 511], dtype=int64), {})
# (array([397, 479, 511], dtype=int64), {})
# (array([397, 478, 510], dtype=int64), {})
# (array([397, 478, 510], dtype=int64), {})
# (array([397, 469, 478, 509], dtype=int64), {})
# (array([396, 468, 478, 509], dtype=int64), {})
# (array([396, 468, 478, 509], dtype=int64), {})
# (array([396, 468, 477, 509], dtype=int64), {})
# (array([397, 467, 477, 508], dtype=int64), {})
# (array([397, 467, 476, 508], dtype=int64), {})
# (array([397, 467, 476, 508], dtype=int64), {})
# (array([397, 466, 475, 508], dtype=int64), {})
# (array([397, 466, 475, 508], dtype=int64), {})
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Python_vscode\blanket.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/d%3A/Python_vscode/blanket.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a>         break
#      <a href='vscode-notebook-cell:/d%3A/Python_vscode/blanket.ipynb#X21sZmlsZQ%3D%3D?line=14'>15</a> peaks = np.array(peaks_l)
# ---> <a href='vscode-notebook-cell:/d%3A/Python_vscode/blanket.ipynb#X21sZmlsZQ%3D%3D?line=15'>16</a> peaks = np.reshape(peaks, (gaussian.shape[1], gaussian.shape[2]))
#
# File d:\Python_vscode\pynapari\Lib\site-packages\numpy\core\fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File d:\Python_vscode\pynapari\Lib\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 858 into shape (858,859)

# %%
plt.imshow(peaks)

# %% [markdown]
# Make a first mask approach, then get the top and calculate a surface among distant points to compute the normal and find a distance value that has the greater pixel intensity.
