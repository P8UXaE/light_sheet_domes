# %%
import skimage as sk
import numpy as np
import matplotlib.pyplot as plt
from skimage.morphology import ball
from skimage.segmentation import watershed
from skimage.filters import rank
from scipy import ndimage as ndi
from copy import copy
import tifffile as tiff

# %%
dome_number = str(56)
image = sk.io.imread('./../ppujol/cellstosegment/'+dome_number+'/cell1_tp22_z190_y720_x830_denoised.tif')

# %%
def normalize_image(im, mult_factor = 1):
    '''
    Normalize image 0-1 and multiply by any factor
    '''
    norm_im = (im - im.min()) / (im.max()-im.min()) * mult_factor
    return norm_im

def reverse_values(im):
    '''
    Reverse values of the image
    '''
    rev_im = im.max()-im
    return rev_im

# %%
z, y, x = 123, 200, 220
delta = 120
division = 1
cell = image[z-int(delta/division):z+int(delta/division), y-delta:y+delta, x-delta:x+delta]
plt.figure(figsize=(10,20))
plt.subplot(121)
plt.title("Slice of image")
plt.imshow(image[int(delta/division)])
plt.subplot(122)
plt.title("Slice of working image")
plt.imshow(cell[int(delta/division)])

print(f"Initial image shape: {image.shape}, working image shape: {cell.shape}")
# Out:
# Initial image shape: (247, 400, 500), working image shape: (240, 240, 240)

# %%
def watershed_process_inner_cell(cell, plots=False, segmentation=True, y='', reduce=''):
    '''
    Segmentation function using the image as it is, not the gradient.
    - 
    '''
    if y == '':
        y = int(delta/division)
    
    cell = normalize_image(cell, 255).astype(np.uint8)
    cell_border = copy(cell)

    denoised = rank.median(cell_border, ball(2)) # It was ball2

    markers = rank.gradient(denoised, ball(5)) < 10 # It was ball5 and <10
    markers = ndi.label(markers)[0]

    labels = watershed(denoised, markers) # Before it was gradient, markers
    all_labels = copy(labels)
    seed_point = (int(delta/division),delta,delta)

    labels[labels != labels[seed_point]] = 0

    labels = sk.morphology.binary_closing(labels, footprint=sk.morphology.ball(5))
    labels = sk.morphology.binary_opening(labels, footprint=sk.morphology.ball(2))

    maskImage = labels*cell_border

    edt = ndi.distance_transform_edt(maskImage)

    if reduce != '':
        edt = sk.morphology.erosion(edt, footprint=ball(reduce))

    if segmentation == False:
        edt = reverse_values(edt)*cell_border
        edt_border = sk.morphology.erosion(edt, footprint=ball(3))

    else:
        edt_border = reverse_values(edt*cell_border)


    if plots == True:

        plt.figure(figsize=(20,8))

        plt.subplot(151)
        plt.title("Median Filter")
        plt.imshow(denoised[y])

        plt.subplot(152)
        plt.title("Labels")
        plt.imshow(labels[y])

        plt.subplot(153)
        plt.title("labels*cell_border")
        plt.imshow(maskImage[y])

        plt.subplot(154)
        plt.title("Euclidian distance transform")
        plt.imshow(edt[y])

        plt.subplot(155)
        plt.title("Edt border")
        plt.imshow(edt_border[y])

    return edt_border, labels, edt, all_labels

# %%
edt_border, label, edt, _ = watershed_process_inner_cell(cell=cell, plots=True, segmentation=False, reduce=3)
_, label, edt, all_labels = watershed_process_inner_cell(cell=edt_border, plots=True, segmentation=True)

# %%
plt.imshow(all_labels[120])

# %%
temp_labels = './../ppujol/cellstosegment/'+dome_number+'/TEMP_all_labels.tif'
cell_write = './../ppujol/cellstosegment/'+dome_number+'/TEMP_image.tif'
enhanced_border_write = './../ppujol/cellstosegment/'+dome_number+'/TEMP_border_image.tif'

all_labels = all_labels.astype(np.uint16)

tiff.imwrite(temp_labels, all_labels, imagej=True)
tiff.imwrite(cell_write, normalize_image(cell, 65535).astype(np.uint16), imagej=True)
tiff.imwrite(enhanced_border_write, normalize_image(edt_border, 65535).astype(np.uint16), imagej=True)

# %% [markdown]
# # NAPARI
#
# ### Now move to napari and open the TEMP files. Select only the masks that correspond to your cell and put them in the masks list below.

# %%
masks = [246, 362, 422, 539, 543, 616, 627, 659, 631, 607, 379]

mask = np.isin(all_labels, masks)

# %%
plt.imshow(mask[120])

# %%
mask_write = './../ppujol/cellstosegment/'+dome_number+'/TEMP_mask.tif'

mask = mask.astype(np.uint16)

tiff.imwrite(mask_write, mask, imagej=True)
